# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/microwave-ovens/pr?sid=j9e%2Cm38%2Co49&p%5B%5D=facets.fulfilled_by%255B%255D%3DFlipkart%2BAssured&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlRvcCBNaWNyb3dhdmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&wid=7.productCard.PMU_V2_2"

# %%
url_req=requests.get(url)

# %%
url_req.status_code #getting 200 means web scrapping is allowed if more or less its not allowed.
# Out:
# 200

# %%
print(url_req.text)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" 
# ...

# %%
soup=BeautifulSoup(url_req.content,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
soup.title
# Out:
# <title>Buy Latest Microwave Ovens Online at Best Prices | Up to 75% Off | Flipkart</title>

# %%
soup.title.string
# Out:
# 'Buy Latest Microwave Ovens Online at Best Prices | Up to 75% Off | Flipkart'

# %%
soup.div
# Out:
# <div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#287
# ...

# %%
soup.div.string #no output as title has only string value

# %%
soup.a
# Out:
# <a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>

# %%
soup.find_all("a") #to see all hyperlink
# Out:
# [<a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="_1_3w1N" href="/account/login?ret=/microwave-ovens/pr%3Fsid%3Dj9e%252Cm38%252Co49%26p%255B%255D%3Dfacets.fulfilled_by%25255B%25255D%253DFlipkart%252BAssured%26ctx%3DeyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlRvcCBNaWNyb3dhdmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%253D%253D%26wid%3D7.productCard.PMU_V2_2">Login</a>,
#  <a class="_3-PJz-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a>,
# ...

# %%
all_links=soup.find_all("a") #all_links variable name
for r in all_links:
    print(r.get('href')) #href refereance
# Out:
# /
# /plus
# /account/login?ret=/microwave-ovens/pr%3Fsid%3Dj9e%252Cm38%252Co49%26p%255B%255D%3Dfacets.fulfilled_by%25255B%25255D%253DFlipkart%252BAssured%26ctx%3DeyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlRvcCBNaWNyb3dhdmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%253D%253D%26wid%3D7.productCard.PMU_V2_2
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?exploreMode=true&preference=FLIPKART
# /home-kitchen/pr?sid=j9e&otracker=categorytree
# /home-kitchen/kitchen-appliances/pr?sid=j9e,m38&otracker=categorytree
# /microwave-ovens/pr?sid=j9e,m38,o49&otracker=categorytree
# /buying-guide/microwave-ovens?sid=j9e,m38,o49&otracker=bg_from_browse_lhs
# /
# /home-kitchen/pr?sid=j9e&marketplace=FLIPKART
# /home-kitchen/kitchen-appliances/pr?sid=j9e,m38&marketplace=FLIPKART
# /microwave-ovens/pr?sid=j9e,m38,o49&marketplace=FLIPKART
# ...

# %%
all_table=soup.find_all('table')

# %%
all_table
# Out:
# []

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim1.flixcart.com" rel="preconnect"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css" rel="stylesheet"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <meta content="noodp" name="robots"/>\n  <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>\n  <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Flipkart.com" name="og_site_name" property="og:s
# ...

# %%
model=soup.findAll('div',{'class':'_4rR01T'})

# %%
model
# Out:
# [<div class="_4rR01T">IFB 23 L Convection Microwave Oven</div>,
#  <div class="_4rR01T">Panasonic 20 L Solo Microwave Oven</div>,
#  <div class="_4rR01T">BAJAJ 17 L Solo Microwave Oven</div>,
#  <div class="_4rR01T">BAJAJ 20 L Grill Microwave Oven</div>,
#  <div class="_4rR01T">SAMSUNG 23 L Solo Microwave Oven</div>,
#  <div class="_4rR01T">Panasonic 20 L Solo Microwave Oven</div>,
#  <div class="_4rR01T">LG 20 L Solo Microwave Oven</div>,
#  <div class="_4rR01T">BAJAJ 20 L Grill Microwave Oven</div>,
#  <div class="_4rR01T">LG 28 L Convection Microwave Oven</div>,
#  <div class="_4rR01T">SAMSUNG 28 L Convection &amp; Grill Microwave Oven</div>,
#  <div class="_4rR01T">LG 20 L Grill Microwave Oven</div>,
#  <div class="_4rR01T">LG 28 L Convection Microwave Oven</div>,
#  <div class="_4rR01T">SAMSUNG 23 L Solo Microwave Oven</div>,
#  <div class="_4rR01T">SAMSUNG 21 L Convection Microwave Oven</div>,
#  <div class="_4rR01T">SAMSUNG 28 L Convection &amp; Grill Microwave Oven</div>,
# ...

# %%
product_name=[]
for i in model:
    p=i.text
    product_name.append(p)

# %%
print(product_name)
# Out:
# ['IFB 23 L Convection Microwave Oven', 'Panasonic 20 L Solo Microwave Oven', 'BAJAJ 17 L Solo Microwave Oven', 'BAJAJ 20 L Grill Microwave Oven', 'SAMSUNG 23 L Solo Microwave Oven', 'Panasonic 20 L Solo Microwave Oven', 'LG 20 L Solo Microwave Oven', 'BAJAJ 20 L Grill Microwave Oven', 'LG 28 L Convection Microwave Oven', 'SAMSUNG 28 L Convection & Grill Microwave Oven', 'LG 20 L Grill Microwave Oven', 'LG 28 L Convection Microwave Oven', 'SAMSUNG 23 L Solo Microwave Oven', 'SAMSUNG 21 L Convection Microwave Oven', 'SAMSUNG 28 L Convection & Grill Microwave Oven', 'IFB 30 L Convection Microwave Oven', 'IFB 20 L Solo Microwave Oven', 'IFB 20 L Solo Microwave Oven', 'LG 28 L Convection Microwave Oven', 'BAJAJ 23 L Convection & Grill Microwave Oven', 'IFB 30 L Convection Microwave Oven', 'LG 20 L Solo Microwave Oven', 'LG 32 L Convection Microwave Oven', 'IFB 30 L Metallic silver Convection Microwave Oven']

# %%
len(product_name) #length
# Out:
# 24

# %%
type(product_name)
# Out:
# list

# %%
model_rating=soup.findAll('div',{'class':'_3LWZlK'})

# %%
model_rating
# Out:
# [<div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
# ...

# %%
product_rating=[]
for i in model_rating:
    r=i.text
    product_rating.append(r)

# %%
product_rating
# Out:
# ['4.4',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.5',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.3']

# %%
len(product_rating)
# Out:
# 24

# %%
type(product_rating)
# Out:
# list

# %%
model_price = soup.findAll('div',{'class':'_30jeq3 _1_WHN1'})

# %%
model_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,090</div>,
#  <div class="_30jeq3 _1_WHN1">₹4,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,369</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,190</div>,
#  <div class="_30jeq3 _1_WHN1">₹5,690</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,090</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,459</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,790</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,899</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,690</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,790</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,590</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,840</div>,
#  <div class="_30jeq3 _1_WHN1">₹5,700</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,189</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,390</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,540</div>,
# ...

# %%
product_price = []
for i in model_price:
    pr=i.text
    product_price.append(pr)
    
print(product_price)
# Out:
# ['₹9,499', '₹6,090', '₹4,999', '₹9,369', '₹6,190', '₹5,690', '₹6,090', '₹9,459', '₹11,790', '₹12,899', '₹7,690', '₹14,999', '₹6,790', '₹9,990', '₹11,590', '₹14,840', '₹5,700', '₹7,189', '₹12,390', '₹9,999', '₹14,540', '₹6,090', '₹15,999', '₹13,590']

# %%
len(product_price)
# Out:
# 24

# %%
product_rating = product_rating[0:24]

# %%
len(product_rating)
# Out:
# 24

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = {'ProductName':product_name,'Price':product_price,'Rating':product_rating}

# %%
df
# Out:
# {'ProductName': ['IFB 23 L Convection Microwave Oven',
#   'Panasonic 20 L Solo Microwave Oven',
#   'BAJAJ 17 L Solo Microwave Oven',
#   'BAJAJ 20 L Grill Microwave Oven',
#   'SAMSUNG 23 L Solo Microwave Oven',
#   'Panasonic 20 L Solo Microwave Oven',
#   'LG 20 L Solo Microwave Oven',
#   'BAJAJ 20 L Grill Microwave Oven',
#   'LG 28 L Convection Microwave Oven',
#   'SAMSUNG 28 L Convection & Grill Microwave Oven',
#   'LG 20 L Grill Microwave Oven',
#   'LG 28 L Convection Microwave Oven',
#   'SAMSUNG 23 L Solo Microwave Oven',
#   'SAMSUNG 21 L Convection Microwave Oven',
#   'SAMSUNG 28 L Convection & Grill Microwave Oven',
#   'IFB 30 L Convection Microwave Oven',
#   'IFB 20 L Solo Microwave Oven',
#   'IFB 20 L Solo Microwave Oven',
#   'LG 28 L Convection Microwave Oven',
#   'BAJAJ 23 L Convection & Grill Microwave Oven',
#   'IFB 30 L Convection Microwave Oven',
#   'LG 20 L Solo Microwave Oven',
#   'LG 32 L Convection Microwave Oven',
# ...

# %%
data = pd.DataFrame(df)
data
# Out:
#                                           ProductName    Price Rating
# 0                  IFB 23 L Convection Microwave Oven   ₹9,499    4.4
# 1                  Panasonic 20 L Solo Microwave Oven   ₹6,090    4.3
# 2                      BAJAJ 17 L Solo Microwave Oven   ₹4,999    4.3
# 3                     BAJAJ 20 L Grill Microwave Oven   ₹9,369    4.4
# 4                    SAMSUNG 23 L Solo Microwave Oven   ₹6,190    4.4
# 5                  Panasonic 20 L Solo Microwave Oven   ₹5,690    4.3
# 6                         LG 20 L Solo Microwave Oven   ₹6,090    4.4
# 7                     BAJAJ 20 L Grill Microwave Oven   ₹9,459    4.2
# 8                   LG 28 L Convection Microwave Oven  ₹11,790    4.4
# 9      SAMSUNG 28 L Convection & Grill Microwave Oven  ₹12,899    4.4
# 10                       LG 20 L Grill Microwave Oven   ₹7,690    4.3
# 11                  LG 28 L Convection Microwave Oven  ₹14,999    4.4
# ...

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df
# Out:
# {'ProductName': ['IFB 23 L Convection Microwave Oven',
#   'Panasonic 20 L Solo Microwave Oven',
#   'BAJAJ 17 L Solo Microwave Oven',
#   'BAJAJ 20 L Grill Microwave Oven',
#   'SAMSUNG 23 L Solo Microwave Oven',
#   'Panasonic 20 L Solo Microwave Oven',
#   'LG 20 L Solo Microwave Oven',
#   'BAJAJ 20 L Grill Microwave Oven',
#   'LG 28 L Convection Microwave Oven',
#   'SAMSUNG 28 L Convection & Grill Microwave Oven',
#   'LG 20 L Grill Microwave Oven',
#   'LG 28 L Convection Microwave Oven',
#   'SAMSUNG 23 L Solo Microwave Oven',
#   'SAMSUNG 21 L Convection Microwave Oven',
#   'SAMSUNG 28 L Convection & Grill Microwave Oven',
#   'IFB 30 L Convection Microwave Oven',
#   'IFB 20 L Solo Microwave Oven',
#   'IFB 20 L Solo Microwave Oven',
#   'LG 28 L Convection Microwave Oven',
#   'BAJAJ 23 L Convection & Grill Microwave Oven',
#   'IFB 30 L Convection Microwave Oven',
#   'LG 20 L Solo Microwave Oven',
#   'LG 32 L Convection Microwave Oven',
# ...

# %%
data
# Out:
#                                           ProductName    Price Rating
# 0                  IFB 23 L Convection Microwave Oven   ₹9,499    4.4
# 1                  Panasonic 20 L Solo Microwave Oven   ₹6,090    4.3
# 2                      BAJAJ 17 L Solo Microwave Oven   ₹4,999    4.3
# 3                     BAJAJ 20 L Grill Microwave Oven   ₹9,369    4.4
# 4                    SAMSUNG 23 L Solo Microwave Oven   ₹6,190    4.4
# 5                  Panasonic 20 L Solo Microwave Oven   ₹5,690    4.3
# 6                         LG 20 L Solo Microwave Oven   ₹6,090    4.4
# 7                     BAJAJ 20 L Grill Microwave Oven   ₹9,459    4.2
# 8                   LG 28 L Convection Microwave Oven  ₹11,790    4.4
# 9      SAMSUNG 28 L Convection & Grill Microwave Oven  ₹12,899    4.4
# 10                       LG 20 L Grill Microwave Oven   ₹7,690    4.3
# 11                  LG 28 L Convection Microwave Oven  ₹14,999    4.4
# ...

# %%
data.columns
# Out:
# Index(['ProductName', 'Price', 'Rating'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductName  24 non-null     object
#  1   Price        24 non-null     object
#  2   Rating       24 non-null     object
# dtypes: object(3)
# memory usage: 704.0+ bytes

# %%
data.describe()
# Out:
#                               ProductName   Price Rating
# count                                  24      24     24
# unique                                 15      22      4
# top     LG 28 L Convection Microwave Oven  ₹6,090    4.4
# freq                                    3       3     12

# %% [markdown]
# ## Null values

# %%
data.isnull()
# Out:
#     ProductName  Price  Rating
# 0         False  False   False
# 1         False  False   False
# 2         False  False   False
# 3         False  False   False
# 4         False  False   False
# 5         False  False   False
# 6         False  False   False
# 7         False  False   False
# 8         False  False   False
# 9         False  False   False
# 10        False  False   False
# 11        False  False   False
# 12        False  False   False
# 13        False  False   False
# 14        False  False   False
# 15        False  False   False
# 16        False  False   False
# 17        False  False   False
# 18        False  False   False
# 19        False  False   False
# 20        False  False   False
# 21        False  False   False
# 22        False  False   False
# 23        False  False   False

# %%
data.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of     ProductName  Price  Rating
# 0         False  False   False
# 1         False  False   False
# 2         False  False   False
# 3         False  False   False
# 4         False  False   False
# 5         False  False   False
# 6         False  False   False
# 7         False  False   False
# 8         False  False   False
# 9         False  False   False
# 10        False  False   False
# 11        False  False   False
# 12        False  False   False
# 13        False  False   False
# 14        False  False   False
# 15        False  False   False
# 16        False  False   False
# 17        False  False   False
# 18        False  False   False
# 19        False  False   False
# 20        False  False   False
# 21        False  False   False
# 22        False  False   False
# 23        False  False   False>

# %%
data.head()
# Out:
#                           ProductName   Price Rating
# 0  IFB 23 L Convection Microwave Oven  ₹9,499    4.4
# 1  Panasonic 20 L Solo Microwave Oven  ₹6,090    4.3
# 2      BAJAJ 17 L Solo Microwave Oven  ₹4,999    4.3
# 3     BAJAJ 20 L Grill Microwave Oven  ₹9,369    4.4
# 4    SAMSUNG 23 L Solo Microwave Oven  ₹6,190    4.4

# %%
data.tail()
# Out:
#                                           ProductName    Price Rating
# 19       BAJAJ 23 L Convection & Grill Microwave Oven   ₹9,999    4.3
# 20                 IFB 30 L Convection Microwave Oven  ₹14,540    4.3
# 21                        LG 20 L Solo Microwave Oven   ₹6,090    4.3
# 22                  LG 32 L Convection Microwave Oven  ₹15,999    4.4
# 23  IFB 30 L Metallic silver Convection Microwave ...  ₹13,590    4.3

# %% [markdown]
# ## To Count number of Categories

# %%
data['ProductName'].value_counts()
# Out:
# LG 28 L Convection Microwave Oven                     3
# Panasonic 20 L Solo Microwave Oven                    2
# BAJAJ 20 L Grill Microwave Oven                       2
# SAMSUNG 23 L Solo Microwave Oven                      2
# LG 20 L Solo Microwave Oven                           2
# SAMSUNG 28 L Convection & Grill Microwave Oven        2
# IFB 30 L Convection Microwave Oven                    2
# IFB 20 L Solo Microwave Oven                          2
# IFB 23 L Convection Microwave Oven                    1
# BAJAJ 17 L Solo Microwave Oven                        1
# LG 20 L Grill Microwave Oven                          1
# SAMSUNG 21 L Convection Microwave Oven                1
# BAJAJ 23 L Convection & Grill Microwave Oven          1
# LG 32 L Convection Microwave Oven                     1
# IFB 30 L Metallic silver Convection Microwave Oven    1
# Name: ProductName, dtype: int64

# %%
data['ProductName'].unique()
# Out:
# array(['IFB 23 L Convection Microwave Oven',
#        'Panasonic 20 L Solo Microwave Oven',
#        'BAJAJ 17 L Solo Microwave Oven',
#        'BAJAJ 20 L Grill Microwave Oven',
#        'SAMSUNG 23 L Solo Microwave Oven', 'LG 20 L Solo Microwave Oven',
#        'LG 28 L Convection Microwave Oven',
#        'SAMSUNG 28 L Convection & Grill Microwave Oven',
#        'LG 20 L Grill Microwave Oven',
#        'SAMSUNG 21 L Convection Microwave Oven',
#        'IFB 30 L Convection Microwave Oven',
#        'IFB 20 L Solo Microwave Oven',
#        'BAJAJ 23 L Convection & Grill Microwave Oven',
#        'LG 32 L Convection Microwave Oven',
#        'IFB 30 L Metallic silver Convection Microwave Oven'], dtype=object)

# %% [markdown]
# # pivot table

# %%
a1=data.copy()
a1=a1.pivot_table('Price',columns='ProductName',aggfunc='sum')

# %%
a1
# Out:
# ProductName BAJAJ 17 L Solo Microwave Oven BAJAJ 20 L Grill Microwave Oven  \
# Price                               ₹4,999                    ₹9,369₹9,459
#
# ProductName BAJAJ 23 L Convection & Grill Microwave Oven  \
# Price                                             ₹9,999
#
# ProductName IFB 20 L Solo Microwave Oven IFB 23 L Convection Microwave Oven  \
# Price                       ₹5,700₹7,189                             ₹9,499
#
# ProductName IFB 30 L Convection Microwave Oven  \
# Price                           ₹14,840₹14,540
#
# ProductName IFB 30 L Metallic silver Convection Microwave Oven  \
# Price                                                  ₹13,590
#
# ProductName LG 20 L Grill Microwave Oven LG 20 L Solo Microwave Oven  \
# Price                             ₹7,690                ₹6,090₹6,090
#
# ProductName LG 28 L Convection Microwave Oven  \
# Price                   ₹11,790₹14,999₹12,390
#
# ProductName LG 32 L Convection Microwave Oven  \
# ...

# %%
plt.bar(data['Price'],data['Rating'])
plt.title('Price v/s Rating',fontsize=15,color='r')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Countplot

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=data['ProductName'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# - LG 28 L Convection Microwave Oven has highest rating among all categories.
